# %% [markdown]
# # Schnell mal eben was plotten
# Einfache Version, nicht interaktiv

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-5,5,0.1)
y=np.sinc(x)
plt.plot(x,y)
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.grid()
